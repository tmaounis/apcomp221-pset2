# %% [markdown]
# # Cleanup on Row 7

# %% [markdown]
# 1. Clean the File
# 2. Handle Corrupt Rows
# 3. Explore Data Set Bias

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### Helper Display Functions

# %%
def display_df(df, nrows=10, ncols=None):
    with pd.option_context('display.max_rows', nrows, 'display.max_columns', ncols):
        display (df)
def print_row(df, row):
    for ctr,i in enumerate(df.iloc[row]):
        print (str(df.columns[ctr])+": "+str(i))

# %% [markdown]
# ## Importing the Data

# %%
df_raw = pd.read_csv("../dirty_sample_small.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-8b25f52726fc> in <module>()
# ----> 1 df_raw = pd.read_csv("../dirty_sample_small.csv", engine='python')
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, rows)
#    2264             content = content[1:]
#    2265
# -> 2266         alldata = self._rows_to_cols(content)
#    2267         data = self._exclude_implicit_index(alldata)
#    2268
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _rows_to_cols(self, content)
#    2907                     msg += '. ' + reason
#    2908
# -> 2909                 self._alert_malformed(msg, row_num + 1)
#    2910
#    2911         # see gh-13320
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _alert_malformed(self, msg, row_num)
#    2674
#    2675         if self.error_bad_lines:
# -> 2676             raise ParserError(msg)
#    2677         elif self.warn_bad_lines:
#    2678             base = 'Skipping line {row_num}: '.format(row_num=row_num)
#
# ParserError: Expected 48 fields in line 652242, saw 49

# %%
df_raw2 = pd.DataFrame([line.strip().split(',') for line in open('../dirty_sample_small.csv', 'r')])

# %%
display_df(df_raw2)
# Out:
#                               0        1           2       3         4   \
# 0                      course_id  user_id  registered  viewed  explored
# 1       HarvardX/PH525.1x/1T2018     7940       False             False
# 2       HarvardX/PH525.1x/1T2018     7940       False             False
# 3       HarvardX/PH525.1x/1T2018     7940       False             False
# 4       HarvardX/PH525.1x/1T2018     7940       False             False
# ...                          ...      ...         ...     ...       ...
# 661482    HarvardX/CS50x/2014_T1  1934738        True   False
# 661483    HarvardX/CS50x/2014_T1  1934738        True   False
# 661484    HarvardX/CS50x/2014_T1  1934738        True   False
# 661485    HarvardX/CS50x/2014_T1  1934738        True   False
# 661486    HarvardX/CS50x/2014_T1  1934738        True   False
#
#                5              6              7               8   \
# 0       certified      completed             ip        cc_by_ip
# 1           False  81.108.107.58             GB  United Kingdom
# 2           False  81.108.107.58             GB  United Kingdom
# 3           False  81.108.107.58             GB  United Kingdom
# 4           False  81.108.107.58             GB  United Kingdom
# ...           ...            ...            ...             ...
# 661482      False          False  71.41.229.179              US
# 661483      False          False  71.41.229.179              US
# 661484      False          False  71.41.229.179              US
# 661485      False          False  71.41.229.179              US
# 661486      False          False  71.41.229.179              US
#
#                    9              10      11             12           13  \
# 0        countryLabel      continent    city         region  subdivision
# 1              Europe  Middlesbrough     MDB  Middlesbrough
# 2              Europe  Middlesbrough     MDB  Middlesbrough
# 3              Europe  Middlesbrough     MDB  Middlesbrough
# 4              Europe  Middlesbrough     MDB  Middlesbrough
# ...               ...            ...     ...            ...          ...
# 661482  United States       Americas  Dallas             TX        Texas
# 661483  United States       Americas  Dallas             TX        Texas
# 661484  United States       Americas  Dallas             TX        Texas
# 661485  United States       Americas  Dallas             TX        Texas
# 661486  United States       Americas  Dallas             TX        Texas
#
#                      14                 15                 16  \
# 0            postalCode    un_major_region  un_economic_group
# 1       Northern Europe  Developed regions
# 2       Northern Europe  Developed regions
# 3       Northern Europe  Developed regions
# 4       Northern Europe  Developed regions
# ...                 ...                ...                ...
# 661482            75201   Northern America  Developed regions
# 661483            75201   Northern America  Developed regions
# 661484            75201   Northern America  Developed regions
# 661485            75201   Northern America  Developed regions
# 661486            75201   Northern America  Developed regions
#
#                           17                 18        19         20   21  \
# 0       un_developing_nation  un_special_region  latitude  longitude  LoE
# 1                                       54.5728   -1.1628
# 2                                       54.5728   -1.1628
# 3                                       54.5728   -1.1628
# 4                                       54.5728   -1.1628
# ...                      ...                ...       ...        ...  ...
# 661482                                            32.7831   -96.8067    p
# 661483                                            32.7831   -96.8067    p
# 661484                                            32.7831   -96.8067    p
# 661485                                            32.7831   -96.8067    p
# 661486                                            32.7831   -96.8067    p
#
#           22      23     24                   25                          26  \
# 0        YoB  gender  grade        passing_grade                  start_time
# 1                       0.7  2018-04-10 08:30:28  2018-04-10 08:30:28.055918
# 2                       0.7  2018-04-10 08:30:28  2018-04-10 08:30:28.055918
# 3                       0.7  2018-04-10 08:30:28  2018-04-10 08:30:28.055918
# 4                       0.7  2018-04-10 08:30:28  2018-04-10 08:30:28.055918
# ...      ...     ...    ...                  ...                         ...
# 661482  1972       m    0.0                  0.6         2013-07-09 01:46:41
# 661483  1972       m    0.0                  0.6         2013-07-09 01:46:41
# 661484  1972       m    0.0                  0.6         2013-07-09 01:46:41
# 661485  1972       m    0.0                  0.6         2013-07-09 01:46:41
# 661486  1972       m    0.0                  0.6         2013-07-09 01:46:41
#
#                                 27          28       29         30  \
# 0                      first_event  last_event  nevents  ndays_act
# 1       2018-04-10 08:30:38.600946           6        2          0
# 2       2018-04-10 08:30:38.600946           6        2          0
# 3       2018-04-10 08:30:38.600946           6        2          0
# 4       2018-04-10 08:30:38.600946           6        2          0
# ...                            ...         ...      ...        ...
# 661482
# 661483
# 661484
# 661485
# 661486
#
#                  31         32            33            34               35  \
# 0       nplay_video  nchapters  nforum_posts  nforum_votes  nforum_endorsed
# 1
# 2
# 3
# 4
# ...             ...        ...           ...           ...              ...
# 661482
# 661483
# 661484
# 661485
# 661486
#
#                     36               37             38       39          40  \
# 0       nforum_threads  nforum_comments  nforum_pinned    roles  nprogcheck
# 1                                              Student        0           0
# 2                                              Student        0           0
# 3                                              Student        0           0
# 4                                              Student        0           0
# ...                ...              ...            ...      ...         ...
# 661482                                                  Student
# 661483                                                  Student
# 661484                                                  Student
# 661485                                                  Student
# 661486                                                  Student
#
#                     41             42     43         44                   45  \
# 0       nproblem_check  nforum_events   mode  is_active    cert_created_date
# 1                    0          audit      1
# 2                    0          audit      1
# 3                    0          audit      1
# 4                    0          audit      1
# ...                ...            ...    ...        ...                  ...
# 661482                                 honor          1  2014-06-06 15:08:24
# 661483                                 honor          1  2014-06-06 15:08:24
# 661484                                 honor          1  2014-06-06 15:08:24
# 661485                                 honor          1  2014-06-06 15:08:24
# 661486                                 honor          1  2014-06-06 15:08:24
#
#                          46           47    48
# 0        cert_modified_date  cert_status  None
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
# ...                     ...          ...   ...
# 661482  2014-09-15 16:35:38   notpassing
# 661483  2014-09-15 16:35:38   notpassing
# 661484  2014-09-15 16:35:38   notpassing
# 661485  2014-09-15 16:35:38   notpassing
# 661486  2014-09-15 16:35:38   notpassing
#
# [661487 rows x 49 columns]

# %%
print_row(df_raw2, 652240)
# Out:
# 0: 6:36:03
# 1: 2014-09-15 17:57:23
# 2: notpassing
# 3:
# 4: None
# 5: None
# 6: None
# 7: None
# 8: None
# 9: None
# 10: None
# 11: None
# 12: None
# 13: None
# 14: None
# 15: None
# 16: None
# 17: None
# 18: None
# 19: None
# 20: None
# 21: None
# 22: None
# 23: None
# 24: None
# 25: None
# 26: None
# 27: None
# 28: None
# 29: None
# 30: None
# 31: None
# 32: None
# 33: None
# 34: None
# 35: None
# 36: None
# 37: None
# 38: None
# 39: None
# 40: None
# 41: None
# 42: None
# 43: None
# 44: None
# 45: None
# 46: None
# 47: None
# 48: None

# %%
#gets ratio of NaNs for each column
def stats_NaN(df):
    df_stats = pd.DataFrame(index=[df.columns], columns=["NaN Ratio"])
    for col in df.columns:
        df_stats["NaN Ratio"][col] = df[col].isna().sum()/len(df) #NaN ratio
    return df_stats.sort_values(by=['NaN Ratio'])

#helps decide what to make dummies for and what to drop
def stats_unique(df, labels):
    df_counts = pd.DataFrame(index=labels,columns=['Unique Count'])
    for l in labels:
        df_counts['Unique Count'][l] = df[l].nunique()
    return df_counts

# %%
stats_NaN(df_raw2)
# Out:
#       NaN Ratio
# 0             0
# 1             0
# 2             0
# 3   0.000270602
# 4   0.000498876
# 5   0.000757384
# 6    0.00102496
# 7    0.00126231
# 8    0.00155407
# 9    0.00181712
# 10   0.00207563
# 11   0.00235379
# 12   0.00264404
# 13   0.00291767
# 14   0.00316257
# 15   0.00343166
# 16   0.00372192
# 17   0.00397589
# 18   0.00421928
# 19   0.00446116
# 20   0.00468339
# 21   0.00495399
# 22   0.00520948
# 23   0.00549066
# 24   0.00576882
# 25   0.00600616
# 26   0.00624804
# 27   0.00652016
# 28   0.00674238
# 29   0.00698426
# 30   0.00722463
# 31   0.00749977
# 32   0.00774618
# 33   0.00801225
# 34   0.00826471
# 35   0.00856706
# 36   0.00882406
# 37   0.00909617
# 38   0.00936526
# 39   0.00962075
# 40   0.00989891
# 41   0.00989891
# 42   0.00989891
# 43   0.00989891
# 44   0.00989891
# 45   0.00989891
# 46   0.00989891
# 47   0.00989891
# 48     0.986152

# %%
df_raw
# Out:
#        course_id,user_id,registered,viewed,explored,certified,completed,ip,cc_by_ip,countryLabel,continent,city,region,subdivision,postalCode,un_major_region,un_economic_group,un_developing_nation,un_special_region,latitude,longitude,LoE,YoB,gender,grade,passing_grade,start_time,first_event,last_event,nevents,ndays_act,nplay_video,nchapters,nforum_posts,nforum_votes,nforum_endorsed,nforum_threads,nforum_comments,nforum_pinned,roles,nprogcheck,nproblem_check,nforum_events,mode,is_active,cert_created_date,cert_modified_date,cert_status
# 0       HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 1       HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 2       HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 3       HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 4       HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 5       HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 6       HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 7       HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 8       HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 9       HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 10      HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 11      HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 12      HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 13      HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 14      HarvardX/PH525.1x/1T2018,7940,False,,False,Fal...
# 15      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 16      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 17      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 18      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 19      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 20      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 21      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 22      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 23      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 24      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 25      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 26      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 27      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 28      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# 29      HarvardX/PH525.1x/1T2018,21193,True,True,False...
# ...                                                   ...
# 661456  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661457  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661458  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661459  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661460  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661461  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661462  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661463  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661464  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661465  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661466  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661467  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661468  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661469  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661470  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661471  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661472  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661473  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661474  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661475  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661476  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661477  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661478  HarvardX/CS50x/2014_T1,1934683,True,False,,Fal...
# 661479  HarvardX/CS50x/2014_T1,1934738,True,False,,Fal...
# 661480  HarvardX/CS50x/2014_T1,1934738,True,False,,Fal...
# 661481  HarvardX/CS50x/2014_T1,1934738,True,False,,Fal...
# 661482  HarvardX/CS50x/2014_T1,1934738,True,False,,Fal...
# 661483  HarvardX/CS50x/2014_T1,1934738,True,False,,Fal...
# 661484  HarvardX/CS50x/2014_T1,1934738,True,False,,Fal...
# 661485  HarvardX/CS50x/2014_T1,1934738,True,False,,Fal...
#
# [661486 rows x 1 columns]

# %%
print_row(df_raw, 652242)
# Out:
# course_id,user_id,registered,viewed,explored,certified,completed,ip,cc_by_ip,countryLabel,continent,city,region,subdivision,postalCode,un_major_region,un_economic_group,un_developing_nation,un_special_region,latitude,longitude,LoE,YoB,gender,grade,passing_grade,start_time,first_event,last_event,nevents,ndays_act,nplay_video,nchapters,nforum_posts,nforum_votes,nforum_endorsed,nforum_threads,nforum_comments,nforum_pinned,roles,nprogcheck,nproblem_check,nforum_events,mode,is_active,cert_created_date,cert_modified_date,cert_status: HarvardX/CS50x/2014_T1,1818882,True,True,True,False,False,173.76.227.129,US,United States,Americas,Newton,MA,Massachusetts,02458,Northern America,Developed regions,,,42.3533,-71.1883,el,2002,m,0.0,0.6,2013-12-04 04:02:20,2013-12-04 04:02:20.199004,2014-04-01 23:30:47.988143,2194,39,680,8,,,,,,,Student,0,0,0,honor,1,2014-06-06 16:36:03,2014-09-15 17:57:23,notpassing,

# %%
print_row(df_raw, 652200)
# Out:
# course_id,user_id,registered,viewed,explored,certified,completed,ip,cc_by_ip,countryLabel,continent,city,region,subdivision,postalCode,un_major_region,un_economic_group,un_developing_nation,un_special_region,latitude,longitude,LoE,YoB,gender,grade,passing_grade,start_time,first_event,last_event,nevents,ndays_act,nplay_video,nchapters,nforum_posts,nforum_votes,nforum_endorsed,nforum_threads,nforum_comments,nforum_pinned,roles,nprogcheck,nproblem_check,nforum_events,mode,is_active,cert_created_date,cert_modified_date,cert_status: HarvardX/CS50x/2014_T1,1934448,False,,False,False,,,,,,,,,,,,,,,b,1990,m,0.0,0.6,2013-07-16 13:53:10,,,,,,,,,,,,,Student,,,,honor,1,2014-06-06 15:15:08,2014-09-15 16:41:22,notpassing,
